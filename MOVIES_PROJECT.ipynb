# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv("/content/TMDB_movie_dataset_v11.csv",on_bad_lines="warn",engine ="python")
# Out:
# /tmp/ipython-input-1721248037.py:1: ParserWarning: Skipping line 1150: unexpected end of data
#
#   movies=pd.read_csv("/content/TMDB_movie_dataset_v11.csv",on_bad_lines="warn",engine ="python")

# %%
movies
# Out:
#           id             title  vote_average  vote_count    status  \
# 0      27205         Inception         8.364       34495  Released
# 1     157336      Interstellar         8.417       32571  Released
# 2        155   The Dark Knight         8.512       30619  Released
# 3      19995            Avatar         7.573       29815  Released
# 4      24428      The Avengers         7.710       29166  Released
# ...      ...               ...           ...         ...       ...
# 1143    1903       Vanilla Sky         6.808        3803  Released
# 1144  696806  The Adam Project         7.052        3799  Released
# 1145   82682    Gangster Squad         6.358        3798  Released
# 1146    9016   Treasure Planet         7.526        3798  Released
# 1147    1885    The Karate Kid         7.181        3798  Released
#
#      release_date     revenue  runtime  adult  \
# 0      2010-07-15   825532764      148  False
# 1      2014-11-05   701729206      169  False
# ...

# %%
movies .shape
# Out:
# (1148, 24)

# %%
movies .sample()
# Out:
#          id              title  vote_average  vote_count    status  \
# 412  464052  Wonder Woman 1984         6.478        7835  Released
#
#     release_date    revenue  runtime  adult                     backdrop_path  \
# 412   2020-12-16  169601036      151  False  /egg7KFi18TSQc1s24RMmR9i2zO6.jpg
#
#      ...     original_title  \
# 412  ...  Wonder Woman 1984
#
#                                               overview popularity  \
# 412  A botched store robbery places Wonder Woman in...     48.128
#
#                           poster_path                      tagline  \
# 412  /8UlWHLMpgZm9bx6QYh0NFoq67TZ.jpg  A new era of wonder begins.
#
#                          genres  \
# 412  Action, Adventure, Fantasy
#
#                                   production_companies  \
# 412  Warner Bros. Pictures, The Stone Quarry, DC Fi...
#
#          production_countries spoken_languages  \
# 412  United States of America          English
#
# ...

# %%
movies.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
movies.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords'],
#       dtype='object')

# %%
movies .sample(5)
# Out:
#         id                    title  vote_average  vote_count    status  \
# 720  38365                Grown Ups         6.359        5577  Released
# 233    745          The Sixth Sense         7.944       10754  Released
# 962   2667  The Blair Witch Project         6.336        4359  Released
# 846  82695           Les Misérables         7.338        4978  Released
# 248  36657                    X-Men         6.996       10530  Released
#
#     release_date    revenue  runtime  adult                     backdrop_path  \
# 720   2010-06-24  271430189      102  False  /wHmhObk0WNb5fL4Y5x4XWUhpLZ4.jpg
# 233   1999-08-06  672806292      107  False  /6TjllWT3cGrPFyqDXurVZ3L8bBi.jpg
# 962   1999-07-14  248639099       81  False  /hSLJKdgzRRvVTOHTwr1qafHpw4n.jpg
# 846   2012-12-18  441809770      158  False  /jd3Z2sAPDavjRxFhfOak6kCrUIG.jpg
# 248   2000-07-13  296339527      104  False  /yGxMIIDSUvaXUjjJuIYZi40Jt3J.jpg
#
#      ...           original_title  \
# ...

# %%
movies["vote_average"]>3
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1143    True
# 1144    True
# 1145    True
# 1146    True
# 1147    True
# Name: vote_average, Length: 1148, dtype: bool

# %%
movies=movies[movies["vote_average"]>3]

# %%
movies .shape
# Out:
# (1148, 24)

# %%
movies .sample(4)
# Out:
#           id            title  vote_average  vote_count    status  \
# 1114  356305         Why Him?         6.376        3874  Released
# 433   278927  The Jungle Book         6.860        7668  Released
# 1079      33       Unforgiven         7.914        3960  Released
# 622     4232           Scream         7.400        6180  Released
#
#      release_date    revenue  runtime  adult  \
# 1114   2016-12-22  118102725      111  False
# 433    2016-04-07  966550600      106  False
# 1079   1992-08-07  159157447      130  False
# 622    1996-12-20  173046663      112  False
#
#                          backdrop_path  ...   original_title  \
# 1114  /o3NEwD06NiD8UFr0ztRd2qCeuFK.jpg  ...         Why Him?
# 433   /tB2w4m0rW62MTufTjRj0gFLMVBP.jpg  ...  The Jungle Book
# 1079  /rvRGFevvZK48onX0PYI1eQLbuJd.jpg  ...       Unforgiven
# 622   /4PPC7fKClu0u7NTbo5xgV4vb5VD.jpg  ...           Scream
#
#                                                overview popularity  \
# ...

# %%
movies["revenue"]>10000000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1143     True
# 1144    False
# 1145     True
# 1146     True
# 1147     True
# Name: revenue, Length: 1148, dtype: bool

# %%
new_movies=movies[movies["revenue"]>100000000]

# %%
new_movies
# Out:
#           id                                        title  vote_average  \
# 0      27205                                    Inception         8.364
# 1     157336                                 Interstellar         8.417
# 2        155                              The Dark Knight         8.512
# 3      19995                                       Avatar         7.573
# 4      24428                                 The Avengers         7.710
# ...      ...                                          ...           ...
# 1142  338953  Fantastic Beasts: The Secrets of Dumbledore         6.721
# 1143    1903                                  Vanilla Sky         6.808
# 1145   82682                               Gangster Squad         6.358
# 1146    9016                              Treasure Planet         7.526
# 1147    1885                               The Karate Kid         7.181
#
#       vote_count    status release_date     revenue  runtime  adult  \
# ...

# %%
new_movies.shape
# Out:
# (885, 24)

# %%
new_movies["status"].value_counts()
# Out:
# status
# Released    885
# Name: count, dtype: int64

# %%
# remove the status coloumn --->

# %%
new_movies.sample(5)
# Out:
#           id                  title  vote_average  vote_count    status  \
# 454   187017         22 Jump Street         6.842        7460  Released
# 580    11321           Seven Pounds         7.613        6362  Released
# 917   138103      The Expendables 3         6.224        4611  Released
# 361     2501    The Bourne Identity         7.463        8618  Released
# 1012   38050  The Adjustment Bureau         6.734        4188  Released
#
#      release_date    revenue  runtime  adult  \
# 454    2014-06-05  331333876      112  False
# 580    2008-12-18  168167691      123  False
# 917    2014-08-07  214700000      126  False
# 361    2002-06-14  214034224      119  False
# 1012   2011-03-03  127869379      106  False
#
#                          backdrop_path  ...         original_title  \
# 454   /kdyYOwpKvvD2fSbwfnMM2YPAzfq.jpg  ...         22 Jump Street
# 580   /rlF1oWTeOGA6RB2g7VsE8PkV7te.jpg  ...           Seven Pounds
# ...

# %%
new_movies["status"].value_counts()
# Out:
# status
# Released    885
# Name: count, dtype: int64

# %%
new_movies
# Out:
#           id                                        title  vote_average  \
# 0      27205                                    Inception         8.364
# 1     157336                                 Interstellar         8.417
# 2        155                              The Dark Knight         8.512
# 3      19995                                       Avatar         7.573
# 4      24428                                 The Avengers         7.710
# ...      ...                                          ...           ...
# 1142  338953  Fantastic Beasts: The Secrets of Dumbledore         6.721
# 1143    1903                                  Vanilla Sky         6.808
# 1145   82682                               Gangster Squad         6.358
# 1146    9016                              Treasure Planet         7.526
# 1147    1885                               The Karate Kid         7.181
#
#       vote_count    status release_date     revenue  runtime  adult  \
# ...

# %%
bins=[3,5,6,8,10]
labels=['Poor(3-5)','Average(5-6)','Good(6-8)','Excellent(8-10)']

# %%
new_movies
# Out:
#           id                                        title  vote_average  \
# 0      27205                                    Inception         8.364
# 1     157336                                 Interstellar         8.417
# 2        155                              The Dark Knight         8.512
# 3      19995                                       Avatar         7.573
# 4      24428                                 The Avengers         7.710
# ...      ...                                          ...           ...
# 1142  338953  Fantastic Beasts: The Secrets of Dumbledore         6.721
# 1143    1903                                  Vanilla Sky         6.808
# 1145   82682                               Gangster Squad         6.358
# 1146    9016                              Treasure Planet         7.526
# 1147    1885                               The Karate Kid         7.181
#
#       vote_count    status release_date     revenue  runtime  adult  \
# ...

# %%
new_movies["Vote_Avg"]=pd.cut(new_movies["vote_average"],bins=bins,labels=labels)
# Out:
# /tmp/ipython-input-1264652254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies["Vote_Avg"]=pd.cut(new_movies["vote_average"],bins=bins,labels=labels)

# %%
new_movies
# Out:
#           id                                        title  vote_average  \
# 0      27205                                    Inception         8.364
# 1     157336                                 Interstellar         8.417
# 2        155                              The Dark Knight         8.512
# 3      19995                                       Avatar         7.573
# 4      24428                                 The Avengers         7.710
# ...      ...                                          ...           ...
# 1142  338953  Fantastic Beasts: The Secrets of Dumbledore         6.721
# 1143    1903                                  Vanilla Sky         6.808
# 1145   82682                               Gangster Squad         6.358
# 1146    9016                              Treasure Planet         7.526
# 1147    1885                               The Karate Kid         7.181
#
#       vote_count    status release_date     revenue  runtime  adult  \
# ...

# %%
new_movies.drop(columns = ["vote_average"], inplace=True)
# Out:
# /tmp/ipython-input-4251006178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies.drop(columns = ["vote_average"], inplace=True)

# %%
new_movies.sample(4)
# Out:
#           id                             title  vote_count    status  \
# 550      331                 Jurassic Park III        6592  Released
# 854   316727          The Purge: Election Year        4919  Released
# 819     4523                         Enchanted        5088  Released
# 1013    1427  Perfume: The Story of a Murderer        4186  Released
#
#      release_date    revenue  runtime  adult  \
# 550    2001-07-18  368780809       92  False
# 854    2016-06-29  118587880      105  False
# 819    2007-11-20  340487652      107  False
# 1013   2006-09-13  135039924      147  False
#
#                          backdrop_path    budget  ...  \
# 550   /hc0rX4AjWy4N39ByuXKbnhjbFia.jpg  93000000  ...
# 854   /a7V3ZXCDAk3P7GjpgfN0IInjh0r.jpg  10000000  ...
# 819   /dOeaWGpouIaONuhRKOj2SrTEWe7.jpg  85000000  ...
# 1013  /kgHYRHQ5BZM1mxsy1MSZepNjMiR.jpg  60000000  ...
#
#                                                overview popularity  \
# ...

# %%
new_movies.drop(columns = ["vote_count"], inplace=True)
# Out:
# /tmp/ipython-input-484419339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies.drop(columns = ["vote_count"], inplace=True)

# %%
new_movies.sample()
# Out:
#          id                           title    status release_date    revenue  \
# 737  505642  Black Panther: Wakanda Forever  Released   2022-11-09  859102154
#
#      runtime  adult                     backdrop_path     budget  \
# 737      162  False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg  250000000
#
#                               homepage  ...  \
# 737  https://wakandaforevertickets.com  ...
#
#                                               overview popularity  \
# 737  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    131.897
#
#                           poster_path   tagline  \
# 737  /sv1xJUazXeYqALzczSZ3O6nkH75.jpg  Forever.
#
#                                  genres production_companies  \
# 737  Action, Adventure, Science Fiction       Marvel Studios
#
#          production_countries  \
# 737  United States of America
#
#                                       spoken_languages  \
# 737  English, French, Haitian; Haitian Creole, Span...
#
# ...

# %%
new_movies["Vote_Avg"].value_counts()
# Out:
# Vote_Avg
# Good(6-8)          749
# Excellent(8-10)     70
# Average(5-6)        64
# Poor(3-5)            2
# Name: count, dtype: int64

# %%
new_movies["revenue"].value_counts().reset_index().sort_values("revenue")
# Out:
#         revenue  count
# 555   100014025      1
# 472   100523181      1
# 447   100541806      1
# 15    100605135      1
# 882   100853753      1
# ..          ...    ...
# 66   2068223624      1
# 873  2264162353      1
# 250  2320250281      1
# 875  2800000000      1
# 4    2923706026      1
#
# [885 rows x 2 columns]

# %%
revenue_bins=[100004215,250000000,500000000,1000000000,2000000000,3000000000]
labels=["ok ok(100004215-250000000)","Avg(250000000-500000000)","Good(500000000-1000000000)","Nice(100000000-2000000000)","So high(2000000000-3000000000)"]

# %%
new_movies.sample(4)
# Out:
#          id                           title    status release_date    revenue  \
# 227    1724             The Incredible Hulk  Released   2008-06-12  163712074
# 903   60308                       Moneyball  Released   2011-09-23  110206216
# 309  438631                            Dune  Released   2021-09-15  402027830
# 231   61791  Rise of the Planet of the Apes  Released   2011-08-03  482860185
#
#      runtime  adult                     backdrop_path     budget  \
# 227      114  False  /xfBnQ4mgf1jYZsscJGJjr6ce0Ar.jpg  150000000
# 903      134  False  /uiHHEFQJLP5dnPe84BU4ZB7j5PL.jpg   50000000
# 309      155  False  /jYEW5xZkZk2WTrdbMGAPFuBqbDc.jpg  165000000
# 231      105  False  /v7JTQy194gRbljdlK4OJhwnOypQ.jpg   93000000
#
#                                               homepage  ...  \
# 227  https://www.marvel.com/movies/the-incredible-hulk  ...
# 903                     http://www.moneyball-movie.com  ...
# 309                         https://www.dunemovie.com/  ...
# ...

# %%
new_movies["revenue_category"]=pd.cut(new_movies["revenue"],bins=revenue_bins,labels=labels)
# Out:
# /tmp/ipython-input-1670509492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies["revenue_category"]=pd.cut(new_movies["revenue"],bins=revenue_bins,labels=labels)

# %%
new_movies["revenue_category"].value_counts()
# Out:
# revenue_category
# ok ok(100004215-250000000)        353
# Avg(250000000-500000000)          313
# Good(500000000-1000000000)        169
# Nice(100000000-2000000000)         44
# So high(2000000000-3000000000)      6
# Name: count, dtype: int64

# %%
new_movies.to_csv("new_movies.csv")

# %%
vot_cat=new_movies["Vote_Avg"].unique().tolist()
vot_cat.insert(0,"all movies")

# %%
vot_cat
# Out:
# ['all movies', 'Excellent(8-10)', 'Good(6-8)', 'Average(5-6)', 'Poor(3-5)']

# %%
new_movies["adult"].unique()
# Out:
# array([False])

# %%
def change_adult(x):
  if x==True:
    return "Adult Movie"
  else:
    return "Not Adult Movie"


new_movies["adult_cat"]=new_movies["adult"].apply(change_adult)
adult_cart=new_movies["adult_cat"].unique().tolist()
adult_cart.insert(0,"all movies")
# Out:
# /tmp/ipython-input-2642350773.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies["adult_cat"]=new_movies["adult"].apply(change_adult)

# %%
new_movies["adult_cat"]=new_movies["adult"].apply(change_adult)
# Out:
# /tmp/ipython-input-458303971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies["adult_cat"]=new_movies["adult"].apply(change_adult)

# %%
adult_cart=new_movies["adult_cat"].unique().tolist()
adult_cart.insert(0,"all movies")

# %%
adult_cart
# Out:
# ['all movies', 'Not Adult Movie']

# %%
revenue_cart=new_movies["revenue_category"].unique().tolist()
revenue_cart.insert(0,"all movies")

# %%
new_movies.shape[0]
# Out:
# 885

# %%
new_movies[new_movies["Vote_Avg"]=="Excellent(8-10)"].reset_index(drop=True)
# Out:
#         id                                title    status release_date  \
# 0    27205                            Inception  Released   2010-07-15
# 1   157336                         Interstellar  Released   2014-11-05
# 2      155                      The Dark Knight  Released   2008-07-16
# 3   299536               Avengers: Infinity War  Released   2018-04-25
# 4      550                           Fight Club  Released   1999-10-15
# ..     ...                                  ...       ...          ...
# 65  315162         Puss in Boots: The Last Wish  Released   2022-12-07
# 66  334543                                 Lion  Released   2016-11-24
# 67     524                               Casino  Released   1995-11-22
# 68  447365       Guardians of the Galaxy Vol. 3  Released   2023-05-03
# 69  569094  Spider-Man: Across the Spider-Verse  Released   2023-05-31
#
#        revenue  runtime  adult                     backdrop_path     budget  \
# ...
